# %% [markdown]
# # EDA
# __import benodigde packages__

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import io

filepath_pyradiomics = "../datasets/OPC_CT_radiomics_TCIA.xlsx"
filepath_clinical = "../datasets/OPC_data_clinical.xlsx"

# %% [markdown]
# __Creëer dataframes__

# %%
df_CT = pd.read_excel(filepath_pyradiomics, header=1, index_col= 0)
df_data = pd.read_excel(filepath_clinical, index_col=0)
#change colname
df_data.rename(columns = {'Trial PatientID':'patientID'}, inplace=True)
# Out:
#         diagnostics_Versions_PyRadiomics diagnostics_Versions_Numpy  \
# patient
# 4                                 v3.1.0                     1.23.1
# 11                                v3.1.0                     1.23.1
# 12                                v3.1.0                     1.23.1
# 13                                v3.1.0                     1.23.1
# 16                                v3.1.0                     1.23.1
# ...                                  ...                        ...
# 596                               v3.1.0                     1.23.1
# 597                               v3.1.0                     1.23.1
# 598                               v3.1.0                     1.23.1
# 600                               v3.1.0                     1.23.1
# 602                               v3.1.0                     1.23.1
#
#         diagnostics_Versions_SimpleITK diagnostics_Versions_PyWavelet  \
# patient
# 4                              2.1.1.2                          1.3.0
# 11                             2.1.1.2                          1.3.0
# 12                             2.1.1.2                          1.3.0
# 13                             2.1.1.2                          1.3.0
# 16                             2.1.1.2                          1.3.0
# ...                                ...                            ...
# 596                            2.1.1.2                          1.3.0
# 597                            2.1.1.2                          1.3.0
# 598                            2.1.1.2                          1.3.0
# 600                            2.1.1.2                          1.3.0
# 602                            2.1.1.2                          1.3.0
#
#         diagnostics_Versions_Python  \
# patient
# 4                             3.9.9
# 11                            3.9.9
# 12                            3.9.9
# 13                            3.9.9
# 16                            3.9.9
# ...                             ...
# 596                           3.9.9
# 597                           3.9.9
# 598                           3.9.9
# 600                           3.9.9
# 602                           3.9.9
#
#                         diagnostics_Configuration_Settings  \
# patient
# 4        {'minimumROIDimensions': 2, 'minimumROISize': ...
# 11       {'minimumROIDimensions': 2, 'minimumROISize': ...
# 12       {'minimumROIDimensions': 2, 'minimumROISize': ...
# 13       {'minimumROIDimensions': 2, 'minimumROISize': ...
# 16       {'minimumROIDimensions': 2, 'minimumROISize': ...
# ...                                                    ...
# 596      {'minimumROIDimensions': 2, 'minimumROISize': ...
# 597      {'minimumROIDimensions': 2, 'minimumROISize': ...
# 598      {'minimumROIDimensions': 2, 'minimumROISize': ...
# 600      {'minimumROIDimensions': 2, 'minimumROISize': ...
# 602      {'minimumROIDimensions': 2, 'minimumROISize': ...
#
#         diagnostics_Configuration_EnabledImageTypes  \
# patient
# 4                                  {'Original': {}}
# 11                                 {'Original': {}}
# 12                                 {'Original': {}}
# 13                                 {'Original': {}}
# 16                                 {'Original': {}}
# ...                                             ...
# 596                                {'Original': {}}
# 597                                {'Original': {}}
# 598                                {'Original': {}}
# 600                                {'Original': {}}
# 602                                {'Original': {}}
#
#                   diagnostics_Image-original_Hash  \
# patient
# 4        fb3c920de5023cb8b33dbd0e708549bd888a02e7
# 11       7bf4c45a945962f79e8a1e25fb387cb42efde3e8
# 12       db3eae06066ea0a2c1213ab60ca7b73b71322170
# 13       c88464e0d8ddef6ab9ed065e169f07df924372fd
# 16       005cf58a253df2d1d68c5a09e190ee25b397f2b3
# ...                                           ...
# 596      a5dfbaf07ff30d03ffb9e5e0b527376b954ab758
# 597      00a7bfc1448f3c4ca7f2954a8523afc100ff00cd
# 598      9364b4f161639bdc53230ca55d8587dfa8836b85
# 600      fd9770c7747bc68ced23122e0b56b9a058be4a3e
# 602      691821c1f6db6c6783bc947fce978e355d5701de
#
#         diagnostics_Image-original_Dimensionality  \
# patient
# 4                                              3D
# 11                                             3D
# 12                                             3D
# 13                                             3D
# 16                                             3D
# ...                                           ...
# 596                                            3D
# 597                                            3D
# 598                                            3D
# 600                                            3D
# 602                                            3D
#
#         diagnostics_Image-original_Spacing  ...  \
# patient                                     ...
# 4                          (1.0, 1.0, 2.0)  ...
# 11                         (1.0, 1.0, 2.0)  ...
# 12                         (1.0, 1.0, 2.0)  ...
# 13                         (1.0, 1.0, 2.0)  ...
# 16                         (1.0, 1.0, 2.0)  ...
# ...                                    ...  ...
# 596                        (1.0, 1.0, 2.0)  ...
# 597                        (1.0, 1.0, 2.0)  ...
# 598                        (1.0, 1.0, 2.0)  ...
# 600                        (1.0, 1.0, 2.0)  ...
# 602                        (1.0, 1.0, 2.0)  ...
#
#         original_glszm_SmallAreaHighGrayLevelEmphasis  \
# patient
# 4                                          907.864344
# 11                                         848.769745
# 12                                         684.010230
# 13                                         989.249064
# 16                                         756.022912
# ...                                               ...
# 596                                        773.759566
# 597                                        549.269398
# 598                                       2414.292906
# 600                                        661.829845
# 602                                        858.464949
#
#          original_glszm_SmallAreaLowGrayLevelEmphasis  \
# patient
# 4                                            0.006301
# 11                                           0.007587
# 12                                           0.002525
# 13                                           0.006041
# 16                                           0.004515
# ...                                               ...
# 596                                          0.003629
# 597                                          0.003796
# 598                                          0.000780
# 600                                          0.005185
# 602                                          0.001188
#
#          original_glszm_ZoneEntropy  original_glszm_ZonePercentage  \
# patient
# 4                          7.132649                       0.051167
# 11                         6.927887                       0.098306
# 12                         6.208071                       0.033012
# 13                         6.570434                       0.098512
# 16                         5.302553                       0.073147
# ...                             ...                            ...
# 596                        7.004167                       0.063441
# 597                        6.018422                       0.047129
# 598                        6.816717                       0.130586
# 600                        6.246855                       0.131427
# 602                        7.173025                       0.057833
#
#         original_glszm_ZoneVariance original_ngtdm_Busyness  \
# patient
# 4                     120199.460605                0.358917
# 11                     20029.066352                0.185269
# 12                    217808.082670                0.534942
# 13                     27079.070038                0.283179
# 16                      2896.273373                0.081612
# ...                             ...                     ...
# 596                   216771.300976                0.835516
# 597                    85007.692990                0.609205
# 598                    12591.675061                0.125596
# 600                     9442.304275                0.265175
# 602                    89634.471619                0.506971
#
#         original_ngtdm_Coarseness original_ngtdm_Complexity  \
# patient
# 4                        0.000557               1107.173820
# 11                       0.001157               1615.980287
# 12                       0.000569                521.151046
# 13                       0.000667               2395.903355
# 16                       0.007506                416.602852
# ...                           ...                       ...
# 596                      0.000230               1464.078326
# 597                      0.000688                492.692583
# 598                      0.000698               8144.264999
# 600                      0.001332               1182.548373
# 602                      0.000504               1121.582561
#
#          original_ngtdm_Contrast  original_ngtdm_Strength
# patient
# 4                       0.003228                 5.580465
# 11                      0.019372                 8.311172
# 12                      0.001233                 3.040387
# 13                      0.010475                 6.464190
# 16                      0.035299                19.760234
# ...                          ...                      ...
# 596                     0.010033                 2.220103
# 597                     0.004769                 3.842956
# 598                     0.009144                18.360216
# 600                     0.053221                 5.869201
# 602                     0.004361                 2.054402
#
# [263 rows x 129 columns]

# %% [markdown]
# De klinische en pyradiomics zijn niet overeenkomend in aantal patiënten. Deze moeten er eerst uitgehaalde worden.

# %%
#get only the number for patient id
df_data['patientID'].replace(to_replace="(OPC-)0{1,4}", value="" , regex=True, inplace=True)

patients = list(df_CT['patient'])
#remove patients in df_data that aren't there in df_CT
df_data = df_data[df_data["patientID"].astype('int64').isin(patients)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Laris\Documents\repos\.venv\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'patientID'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\Laris\Documents\repos\p_2.2\DD-radiomics\EDA_radionomics.ipynb Cell 6 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Laris/Documents/repos/p_2.2/DD-radiomics/EDA_radionomics.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> #get only the number for patient id
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Laris/Documents/repos/p_2.2/DD-radiomics/EDA_radionomics.ipynb#X25sZmlsZQ%3D%3D?line=1'>2</a> df_data['patientID'].replace(to_replace="(OPC-)0{1,4}", value="" , regex=True, inplace=True)
#       <a href='vscode-notebook-cell:/c%3A/Users/Laris/Documents/repos/p_2.2/DD-radiomics/EDA_radionomics.ipynb#X25sZmlsZQ%3D%3D?line=3'>4</a> patients = list(df_CT['patient'])
#       <a href='vscode-notebook-cell:/c%3A/Users/Laris/Documents/repos/p_2.2/DD-radiomics/EDA_radionomics.ipynb#X25sZmlsZQ%3D%3D?line=4'>5</a> #remove patients in df_data that aren't there in df_CT
#
# File c:\Users\Laris\Documents\repos\.venv\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File c:\Users\Laris\Documents\repos\.venv\Lib\site-packages\pandas\core\indexes\base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'patientID'

# %% [markdown]
# __Data laten zien__

# %% [markdown]
# __File OPC_data_clinical.xlsx__

# %%
df_data
# Out:
#     Trial PatientID  Age at diagnosis     Sex ECOG Performance Status Scale  \
# 0         OPC-00004         59.730000    Male                        ECOG 0
# 1         OPC-00011         67.460000    Male                        ECOG 0
# 2         OPC-00012         73.460000    Male                        ECOG 0
# 3         OPC-00013         67.250000    Male                        ECOG 0
# 4         OPC-00014         63.730000    Male                        ECOG 0
# ..              ...               ...     ...                           ...
# 295       OPC-00596         58.091667  Female                        ECOG 0
# 296       OPC-00597         68.280556    Male                        ECOG 1
# 297       OPC-00598         58.288889    Male                        ECOG 0
# 298       OPC-00600         53.947222  Female                        ECOG 0
# 299       OPC-00602         56.963889    Male                        ECOG 1
#
#      Smoking PY  Smoking Hx  Drinking hx     Ds Site          Subsite    T  \
# 0          40.0     Current        light  Oropharynx      Soft Palate   T3
# 1          49.0     Current     Moderate  Oropharynx           Tonsil  T4a
# 2          20.0   Ex-smoker  non-drinker  Oropharynx   Base of Tongue   T3
# 3           0.0  Non-smoker  non-drinker  Oropharynx           Tonsil   T3
# 4           0.0   Ex-smoker  non-drinker  Oropharynx   Base of Tongue   T1
# ..          ...         ...          ...         ...              ...  ...
# 295         5.0   Ex-smoker        light  Oropharynx    Tonsil Pillar   T3
# 296         0.0  Non-smoker  non-drinker  Oropharynx   Base of Tongue   T2
# 297        50.0   Ex-smoker   ex-drinker  Oropharynx    Tonsil Pillar   T2
# 298         5.0     Current     Moderate  Oropharynx  Tonsillar Fossa   T2
# 299        60.0   Ex-smoker  non-drinker  Oropharynx           Tonsil   T3
#
#      ... Status  Cause of Death Local Failure  \
# 0    ...  Alive             NaN           NaN
# 1    ...  Alive             NaN           NaN
# 2    ...  Alive             NaN           NaN
# 3    ...  Alive             NaN           NaN
# 4    ...  Alive             NaN           NaN
# ..   ...    ...             ...           ...
# 295  ...  Alive             NaN           NaN
# 296  ...  Alive             NaN           NaN
# 297  ...   Dead    Other Cancer           NaN
# 298  ...   Dead     Other Cause           Yes
# 299  ...   Dead  Index Ca-On Tx           NaN
#
#     Time interval from the date of diagnosis to the date of  local failure (days)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 295                                                NaN
# 296                                                NaN
# 297                                                NaN
# 298                                              269.0
# 299                                                NaN
#
#     Regional Failure  \
# 0                NaN
# 1         Persistent
# 2                NaN
# 3                NaN
# 4                NaN
# ..               ...
# 295              NaN
# 296              NaN
# 297              NaN
# 298              NaN
# 299              NaN
#
#     Time interval from the date of diagnosis to the date of  regional failure (days)  \
# 0                                                  NaN
# 1                                                 35.0
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 295                                                NaN
# 296                                                NaN
# 297                                                NaN
# 298                                                NaN
# 299                                                NaN
#
#     Distant Failure  \
# 0               NaN
# 1               Yes
# 2               NaN
# 3               NaN
# 4               NaN
# ..              ...
# 295             NaN
# 296             NaN
# 297             NaN
# 298             NaN
# 299             NaN
#
#      Time interval from the date of diagnosis to the date of  distant failure (days)  \
# 0                                                  NaN
# 1                                                148.0
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 295                                                NaN
# 296                                                NaN
# 297                                                NaN
# 298                                                NaN
# 299                                                NaN
#
#      Second Primary  \
# 0               Yes
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ..              ...
# 295             NaN
# 296             Yes
# 297             Yes
# 298             NaN
# 299             NaN
#
#      Time interval from the date of diagnosis to the date of 2nd cancer (days)
# 0                                                831.0
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 295                                                NaN
# 296                                                0.0
# 297                                             2758.0
# 298                                                NaN
# 299                                                NaN
#
# [300 rows x 33 columns]

# %% [markdown]
# Dit is een dataset met alle klinische info van de patiënten.
# Met de volgende kollomen. Een aantal zijn voor de handliggend, deze zal ik niet uitleggen.
# Trial PatientID
# Age at diagnosis
# Sex
# ECOG Performance Status Scale, The ECOG Performance Status Scale is one such measurement. It describes a patient’s level of functioning in terms of their ability to care for themself, daily activity, and physical ability (walking, working, etc.).(https://ecog-acrin.org/resources/ecog-performance-status/)
# Smoking PY, pack-year. Is het gelijk aan een pack per dag in 1 jaar.
# Smoking Hx, status van.
# Drinking hx, status van.
# Ds Site, site of tumor.
# Subsite,
#     TNM score: The TNM Classification of Malignant Tumors (TNM) is a globally recognised standard for classifying the anatomical extent of the spread of
#         Primary Tumor (T)
#         T0 No evidence of primary tumor
#         T1, T2, T3, T4 Increasing size and/or local extension of the primary tumor
#         TX Primary tumor cannot be assessed
#
#         Regional Lymph Nodes (N)
#         N0 No regional lymph node metastases
#         N1, N2, N3 Increasing number or extent of regional lymph node involvement
#         NX Regional lymph nodes cannot be assessed
#
#         Distant Metastasis (M)
#         M0 No distant metastases
#         M1 Distant metastases present
# T describes the size of the original (primary) tumor and whether it has invaded nearby tissue,
# N describes nearby (regional) lymph nodes that are involved,
# M describes distant metastasis (spread of cancer from one part of the body to another)
# Stage(AJCC 7th Edition),
#      Stage Classifi cations. Five stage classifi cations may be described for each site (Table 1.4 ):
#         Clinical stage/pretreatment stage, designated as cTNM or TNM
#         Pathologic stage, designated as pTNM
#         Post therapy or postneoadjuvant therapy stage, designated as ycTNM or ypTNM
#         Retreatment or recurrence classifi cation, designated as rTNM
#         Autopsy classifi cation, designated as aTNM
# Path
# HPV_p16 status (IHC)
# Primary Treatment
# Chemotherapy
# Time interval from the date of diagnosis to the RT start date (days)
# Time interval from the date of diagnosis to the RT end date (days)
# Dose (gy)
# Number of fractions
# RT Tech
# Time interval from the date of diagnosis to the date of last FU  (days)
# Status
# Cause of Death
# Local Failure
# Time interval from the date of diagnosis to the date of  local failure (days)
# Regional Failure
# Time interval from the date of diagnosis to the date of  regional failure (days)
# Distant Failure
# Time interval from the date of diagnosis to the date of  distant failure (days)
# Second Primary
# Time interval from the date of diagnosis to the date of 2nd cancer (days)']

# %% [markdown]
# __File OPC_CT_radiomics_TCIA.xlsx__

# %%
df_CT
# Out:
#      patient diagnostics_Versions_PyRadiomics diagnostics_Versions_Numpy  \
# 0          4                           v3.1.0                     1.23.1
# 1         11                           v3.1.0                     1.23.1
# 2         12                           v3.1.0                     1.23.1
# 3         13                           v3.1.0                     1.23.1
# 4         16                           v3.1.0                     1.23.1
# ..       ...                              ...                        ...
# 258      596                           v3.1.0                     1.23.1
# 259      597                           v3.1.0                     1.23.1
# 260      598                           v3.1.0                     1.23.1
# 261      600                           v3.1.0                     1.23.1
# 262      602                           v3.1.0                     1.23.1
#
#     diagnostics_Versions_SimpleITK diagnostics_Versions_PyWavelet  \
# 0                          2.1.1.2                          1.3.0
# 1                          2.1.1.2                          1.3.0
# 2                          2.1.1.2                          1.3.0
# 3                          2.1.1.2                          1.3.0
# 4                          2.1.1.2                          1.3.0
# ..                             ...                            ...
# 258                        2.1.1.2                          1.3.0
# 259                        2.1.1.2                          1.3.0
# 260                        2.1.1.2                          1.3.0
# 261                        2.1.1.2                          1.3.0
# 262                        2.1.1.2                          1.3.0
#
#     diagnostics_Versions_Python  \
# 0                         3.9.9
# 1                         3.9.9
# 2                         3.9.9
# 3                         3.9.9
# 4                         3.9.9
# ..                          ...
# 258                       3.9.9
# 259                       3.9.9
# 260                       3.9.9
# 261                       3.9.9
# 262                       3.9.9
#
#                     diagnostics_Configuration_Settings  \
# 0    {'minimumROIDimensions': 2, 'minimumROISize': ...
# 1    {'minimumROIDimensions': 2, 'minimumROISize': ...
# 2    {'minimumROIDimensions': 2, 'minimumROISize': ...
# 3    {'minimumROIDimensions': 2, 'minimumROISize': ...
# 4    {'minimumROIDimensions': 2, 'minimumROISize': ...
# ..                                                 ...
# 258  {'minimumROIDimensions': 2, 'minimumROISize': ...
# 259  {'minimumROIDimensions': 2, 'minimumROISize': ...
# 260  {'minimumROIDimensions': 2, 'minimumROISize': ...
# 261  {'minimumROIDimensions': 2, 'minimumROISize': ...
# 262  {'minimumROIDimensions': 2, 'minimumROISize': ...
#
#     diagnostics_Configuration_EnabledImageTypes  \
# 0                              {'Original': {}}
# 1                              {'Original': {}}
# 2                              {'Original': {}}
# 3                              {'Original': {}}
# 4                              {'Original': {}}
# ..                                          ...
# 258                            {'Original': {}}
# 259                            {'Original': {}}
# 260                            {'Original': {}}
# 261                            {'Original': {}}
# 262                            {'Original': {}}
#
#               diagnostics_Image-original_Hash  \
# 0    fb3c920de5023cb8b33dbd0e708549bd888a02e7
# 1    7bf4c45a945962f79e8a1e25fb387cb42efde3e8
# 2    db3eae06066ea0a2c1213ab60ca7b73b71322170
# 3    c88464e0d8ddef6ab9ed065e169f07df924372fd
# 4    005cf58a253df2d1d68c5a09e190ee25b397f2b3
# ..                                        ...
# 258  a5dfbaf07ff30d03ffb9e5e0b527376b954ab758
# 259  00a7bfc1448f3c4ca7f2954a8523afc100ff00cd
# 260  9364b4f161639bdc53230ca55d8587dfa8836b85
# 261  fd9770c7747bc68ced23122e0b56b9a058be4a3e
# 262  691821c1f6db6c6783bc947fce978e355d5701de
#
#     diagnostics_Image-original_Dimensionality  ...  \
# 0                                          3D  ...
# 1                                          3D  ...
# 2                                          3D  ...
# 3                                          3D  ...
# 4                                          3D  ...
# ..                                        ...  ...
# 258                                        3D  ...
# 259                                        3D  ...
# 260                                        3D  ...
# 261                                        3D  ...
# 262                                        3D  ...
#
#     original_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                      907.864344
# 1                                      848.769745
# 2                                      684.010230
# 3                                      989.249064
# 4                                      756.022912
# ..                                            ...
# 258                                    773.759566
# 259                                    549.269398
# 260                                   2414.292906
# 261                                    661.829845
# 262                                    858.464949
#
#     original_glszm_SmallAreaLowGrayLevelEmphasis  original_glszm_ZoneEntropy  \
# 0                                       0.006301                    7.132649
# 1                                       0.007587                    6.927887
# 2                                       0.002525                    6.208071
# 3                                       0.006041                    6.570434
# 4                                       0.004515                    5.302553
# ..                                           ...                         ...
# 258                                     0.003629                    7.004167
# 259                                     0.003796                    6.018422
# 260                                     0.000780                    6.816717
# 261                                     0.005185                    6.246855
# 262                                     0.001188                    7.173025
#
#      original_glszm_ZonePercentage  original_glszm_ZoneVariance  \
# 0                         0.051167                120199.460605
# 1                         0.098306                 20029.066352
# 2                         0.033012                217808.082670
# 3                         0.098512                 27079.070038
# 4                         0.073147                  2896.273373
# ..                             ...                          ...
# 258                       0.063441                216771.300976
# 259                       0.047129                 85007.692990
# 260                       0.130586                 12591.675061
# 261                       0.131427                  9442.304275
# 262                       0.057833                 89634.471619
#
#     original_ngtdm_Busyness original_ngtdm_Coarseness  \
# 0                  0.358917                  0.000557
# 1                  0.185269                  0.001157
# 2                  0.534942                  0.000569
# 3                  0.283179                  0.000667
# 4                  0.081612                  0.007506
# ..                      ...                       ...
# 258                0.835516                  0.000230
# 259                0.609205                  0.000688
# 260                0.125596                  0.000698
# 261                0.265175                  0.001332
# 262                0.506971                  0.000504
#
#     original_ngtdm_Complexity original_ngtdm_Contrast  original_ngtdm_Strength
# 0                 1107.173820                0.003228                 5.580465
# 1                 1615.980287                0.019372                 8.311172
# 2                  521.151046                0.001233                 3.040387
# 3                 2395.903355                0.010475                 6.464190
# 4                  416.602852                0.035299                19.760234
# ..                        ...                     ...                      ...
# 258               1464.078326                0.010033                 2.220103
# 259                492.692583                0.004769                 3.842956
# 260               8144.264999                0.009144                18.360216
# 261               1182.548373                0.053221                 5.869201
# 262               1121.582561                0.004361                 2.054402
#
# [263 rows x 130 columns]

# %% [markdown]
# Dit is een dataset met informatie over de gemaakte CT scans van de region of interest(ROI).
# Deze zijn extract met behulp van pyradiomics.
#
# Er zijn 130 kollomen. Die verdeelbaar zijn in 8 groepen:
# basic information,
# shape features
# first order features
# GLCM features
# GLDM features
# GLRLM features
# GLZSM features
# NGTDM features

# %%
basic_information = 0 
shape_features = 23
first_order_features = 38
GLCM_features = 55 
GLDM_features = 79
GLRLM_features = 93 
GLZSM_features = 109 
NGTDM_features = 125

# %% [markdown]
# allemaal algemene info van de kollommen

# %%
#get info of dataframe
buffer = io.StringIO()
df_CT.info(buf=buffer, verbose=True)
s = buffer.getvalue()
with open("df_CT_info.txt", "w",
          encoding="utf-8") as f:  
    f.write(s)

# %% [markdown]
# eh niet echt iets zichtbaar in die info want te veel kollommen
# Dus eerst focussen op de eerste feature, de shape features.

# %%
#get shapefeature
df_shape = df_CT.iloc[:, shape_features: first_order_features-1]

df_shape.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263 entries, 0 to 262
# Data columns (total 14 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   original_shape_Elongation               263 non-null    float64
#  1   original_shape_Flatness                 263 non-null    float64
#  2   original_shape_LeastAxisLength          263 non-null    float64
#  3   original_shape_MajorAxisLength          263 non-null    float64
#  4   original_shape_Maximum2DDiameterColumn  263 non-null    float64
#  5   original_shape_Maximum2DDiameterRow     263 non-null    float64
#  6   original_shape_Maximum2DDiameterSlice   263 non-null    float64
#  7   original_shape_Maximum3DDiameter        263 non-null    float64
#  8   original_shape_MeshVolume               263 non-null    float64
#  9   original_shape_MinorAxisLength          263 non-null    float64
#  10  original_shape_Sphericity               263 non-null    float64
#  11  original_shape_SurfaceArea              263 non-null    float64
#  12  original_shape_SurfaceVolumeRatio       263 non-null    float64
#  13  original_shape_VoxelVolume              263 non-null    int64
# dtypes: float64(13), int64(1)
# memory usage: 28.9 KB

# %%
w_23 = df_CT.iloc[:,23:]

#correlatie?
corr = w_23.corr()

#corr higher than 0.8
corr_80 = corr.ge(0.8)


names = {}
#get rownames
for col_name in corr_80:
    row = list(corr_80[corr_80.loc[col_name] == True].index) 
    #remove the crossing
    row.remove(col_name)
    if row:
        names[col_name] = row

#dataframe
print(len(set(names)))
# Out:
# 87
